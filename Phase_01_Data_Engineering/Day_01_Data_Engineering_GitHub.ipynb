# %% [markdown]
# <a href="https://colab.research.google.com/github/divyasaminathan02/Sridivyadharshini-Codeboosters-Internship-2026/blob/main/Phase_01_Data_Engineering/Day_01_Data_Engineering_GitHub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df=pd.read_csv('student_performance.csv')

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
#prints first 5 rows
df.head()
# Out:
#    student_id          name  age  gender        department  semester  \
# 0        1001  Aarav Sharma   19    Male  Computer Science         2
# 1        1002   Priya Patel   20  Female  Computer Science         2
# 2        1003   Rohit Verma   19    Male       Electronics         2
# 3        1004   Sneha Reddy   20  Female        Mechanical         2
# 4        1005    Arjun Nair   19    Male  Computer Science         2
#
#    math_score  science_score  english_score  programming_score  \
# 0          85             78             72                 91
# 1          76             82             88                 79
# 2          65             74             61                 55
# 3          70             80             75                 48
# 4          92             88             81                 95
#
#    attendance_percentage       city  admission_year
# 0                     92     Mumbai            2023
# 1                     87  Ahmedabad            2023
# ...

# %%
#prints last 5 rows and improves accuracy
df.tail()
# Out:
#     student_id            name  age  gender        department  semester  \
# 25        1026      Rekha Nair   20  Female       Electronics         2
# 26        1027   Gaurav Shukla   21    Male  Computer Science         2
# 27        1028   Sunita Pillai   19  Female             Civil         2
# 28        1029      Nitin Jain   20    Male        Mechanical         2
# 29        1030  Akanksha Yadav   19  Female  Computer Science         2
#
#     math_score  science_score  english_score  programming_score  \
# 25          72             77             73                 63
# 26          84             79             75                 87
# 27          60             65             68                 39
# 28          75             76             70                 50
# 29          91             93             87                 94
#
#     attendance_percentage                city  admission_year
# 25                     82               Kochi            2023
# ...

# %%
#prints rows and cols
print("Shape of dataset:",df.shape)
# 0->rows
print("Number of students(rows):",df.shape[0])
# 1->cols
print("Number of columns:",df.shape[1])
# Out:
# Shape of dataset: (30, 13)
# Number of students(rows): 30
# Number of columns: 13

# %% [markdown]
# columns is an attribute that give sus all column names.
# tolist() converts it from a pandas index objext into regular Python list
# A list in Python is a collection of items inside square Brackets[]
# This shows us all 13 column names

# %%
print("Columns in the dataset:")
#'columns' attribute that gives all the column names
#'tolist()'converts pandas index object into a regular python list
print(df.columns.tolist())
# Out:
# Columns in the dataset:
# ['student_id', 'name', 'age', 'gender', 'department', 'semester', 'math_score', 'science_score', 'english_score', 'programming_score', 'attendance_percentage', 'city', 'admission_year']

# %%
df.columns.tolist()
# Out:
# ['student_id',
#  'name',
#  'age',
#  'gender',
#  'department',
#  'semester',
#  'math_score',
#  'science_score',
#  'english_score',
#  'programming_score',
#  'attendance_percentage',
#  'city',
#  'admission_year']

# %%
#shows the datatype of every column
print("Data types:")
print("Data types of columns:",df.dtypes)
# Out:
# Data types:
# Data types of columns: student_id                int64
# name                     object
# age                       int64
# gender                   object
# department               object
# semester                  int64
# math_score                int64
# science_score             int64
# english_score             int64
# programming_score         int64
# attendance_percentage     int64
# city                     object
# admission_year            int64
# dtype: object

# %%
# generates a statistical summary
df.describe()
# Out:
#         student_id        age  semester  math_score  science_score  \
# count    30.000000  30.000000      30.0   30.000000      30.000000
# mean   1015.500000  19.733333       2.0   76.066667      77.833333
# std       8.803408   0.739680       0.0   11.467896       8.554423
# min    1001.000000  19.000000       2.0   56.000000      61.000000
# 25%    1008.250000  19.000000       2.0   67.250000      71.250000
# 50%    1015.500000  20.000000       2.0   75.500000      78.000000
# 75%    1022.750000  20.000000       2.0   85.750000      83.750000
# max    1030.000000  21.000000       2.0   95.000000      93.000000
#
#        english_score  programming_score  attendance_percentage  admission_year
# count      30.000000          30.000000              30.000000            30.0
# mean       74.166667          67.600000              84.500000          2023.0
# std        10.003735          21.041175               9.379913             0.0
# ...

# %% [markdown]
# isnull checks every cell and returns True if the cell is empty(missing) ,False if it has a value
# .sum() counts how many True values exists per column

# %%
print("Missing values in each column")
print(df.isnull().sum())

print("\nTotal missing values:",df.isnull().sum().sum())
# Out:
# Missing values in each column
# student_id               0
# name                     0
# age                      0
# gender                   0
# department               0
# semester                 0
# math_score               0
# science_score            0
# english_score            0
# programming_score        0
# attendance_percentage    0
# city                     0
# admission_year           0
# dtype: int64
#
# Total missing values: 0

# %%
print("Student Names:")
print(df['name'])
print(df['english_score'])
print(df['semester'])
print(df['age'])
# Out:
# Student Names:
# 0       Aarav Sharma
# 1        Priya Patel
# 2        Rohit Verma
# 3        Sneha Reddy
# 4         Arjun Nair
# 5        Meera Joshi
# 6        Kiran Kumar
# 7        Divya Singh
# 8       Rahul Mishra
# 9         Ananya Das
# 10       Vikram Iyer
# 11       Pooja Gupta
# 12        Suresh Rao
# 13     Kavya Nambiar
# 14       Ajay Tiwari
# 15      Ritu Agarwal
# 16      Manoj Pandey
# 17    Swati Kulkarni
# 18    Deepak Chauhan
# 19      Nisha Kapoor
# 20     Harish Pillai
# 21       Tanvi Mehta
# 22      Sanjay Dubey
# 23     Preeti Saxena
# 24         Amit Bose
# 25        Rekha Nair
# 26     Gaurav Shukla
# 27     Sunita Pillai
# 28        Nitin Jain
# 29    Akanksha Yadav
# Name: name, dtype: object
# 0     72
# 1     88
# 2     61
# 3     75
# 4     81
# 5     70
# 6     65
# 7     84
# 8     58
# 9     90
# 10    68
# 11    79
# 12    77
# 13    82
# 14    64
# 15    86
# 16    55
# 17    85
# 18    62
# 19    81
# 20    67
# 21    88
# 22    59
# 23    76
# ...

# %% [markdown]
# unique() - returns only the unique values in the column
# value_counts() -number of times each unique value appears

# %%
print("Departments in this dataset:")
print(df['department'].unique())

print("\nHow many students per department:")
print(df['department'].value_counts())
# Out:
# Departments in this dataset:
# ['Computer Science' 'Electronics' 'Mechanical' 'Civil']
#
# How many students per department:
# department
# Computer Science    13
# Electronics          6
# Mechanical           6
# Civil                5
# Name: count, dtype: int64

# %%
cs_students=df[df['department'] == 'Computer Science']
#this is called boolean filtering or conditional selection
print(f"Number of Computer Science students: {len(cs_students)}")
print("\nComputer Science students")
print(cs_students[['name','math_score','programming_score','attendance_percentage']])
# Out:
# Number of Computer Science students: 13
#
# Computer Science students
#               name  math_score  programming_score  attendance_percentage
# 0     Aarav Sharma          85                 91                     92
# 1      Priya Patel          76                 79                     87
# 4       Arjun Nair          92                 95                     90
# 7      Divya Singh          88                 93                     96
# 9       Ananya Das          95                 97                     98
# 12      Suresh Rao          83                 88                     88
# 14     Ajay Tiwari          71                 76                     75
# 17  Swati Kulkarni          90                 92                     94
# 19    Nisha Kapoor          79                 83                     89
# 21     Tanvi Mehta          93                 96                     97
# 24       Amit Bose          86                 89                     91
# ...

# %%
high_attendance=df[df['attendance_percentage']>90]
print(f"Students with attendance above 90%: {len(high_attendance)}")
print(high_attendance[['name','department','attendance_percentage']])
# Out:
# Students with attendance above 90%: 10
#               name        department  attendance_percentage
# 0     Aarav Sharma  Computer Science                     92
# 3      Sneha Reddy        Mechanical                     95
# 7      Divya Singh  Computer Science                     96
# 9       Ananya Das  Computer Science                     98
# 13   Kavya Nambiar        Mechanical                     91
# 15    Ritu Agarwal       Electronics                     93
# 17  Swati Kulkarni  Computer Science                     94
# 21     Tanvi Mehta  Computer Science                     97
# 24       Amit Bose  Computer Science                     91
# 29  Akanksha Yadav  Computer Science                     95

# %% [markdown]
# loc -> locates the row by index

# %%
df['total_score']=df['math_score']+df['science_score']+df['programming_score']+df['english_score']

top_student=df.loc[df['total_score'].idxmax()]

print("Top student : ")
print(f"Name : {top_student['name']}")
print(f"Department : {top_student['department']}")
print(f"Total Score : {top_student['total_score']}")
print(f"Attendance : {top_student['attendance_percentage']}")
# Out:
# Top student :
# Name : Ananya Das
# Department : Computer Science
# Total Score : 371
# Attendance : 98

# %% [markdown]
# groups all rows by dept value

# %%
dept_avg=df.groupby('department')['total_score'].mean().round(2)
print("Average Total Score by Department")
print(dept_avg)
# Out:
# Average Total Score by Department
# department
# Civil               235.80
# Computer Science    340.15
# Electronics         277.50
# Mechanical          267.33
# Name: total_score, dtype: float64

# %%
df_sorted=df.sort_values(by='total_score',ascending=False)

print("Top 10 students by total score : ")
print(df_sorted[['name','department','total_score','attendance_percentage']].head(10))
# Out:
# Top 10 students by total score :
#               name        department  total_score  attendance_percentage
# 9       Ananya Das  Computer Science          371                     98
# 21     Tanvi Mehta  Computer Science          367                     97
# 29  Akanksha Yadav  Computer Science          365                     95
# 4       Arjun Nair  Computer Science          356                     90
# 7      Divya Singh  Computer Science          356                     96
# 17  Swati Kulkarni  Computer Science          354                     94
# 24       Amit Bose  Computer Science          336                     91
# 12      Suresh Rao  Computer Science          334                     88
# 19    Nisha Kapoor  Computer Science          327                     89
# 0     Aarav Sharma  Computer Science          326                     92

# %% [markdown]
# PRACTICE QUESTIONS
# Try solving these on your own.
#
# 1. How many students are from the Electronics department?
# 2. What is the average attendance of female students?
# 3. Who is the student with the lowest programming score?
# 4. How many students scored above 80 in math?
# 5. What is the avg total_score for students with attendance above 90%?

# %%
el_students=df[df['department'] == 'Electronics']
print(f"Number of Electronics students: {len(el_students)}")
# Out:
# Number of Electronics students: 6

# %%
att_avg=df.groupby('gender')['attendance_percentage'].mean().round(2)
print("Average Attendance of female students")
print(att_avg)
# Out:
# Average Attendance of female students
# gender
# Female    88.53
# Male      80.47
# Name: attendance_percentage, dtype: float64

# %%
df_sorted=df.sort_values(by='programming_score',ascending=True)

print("Top 10 students by total score : ")
print(df_sorted[['name','department','total_score','attendance_percentage']].head(1))
# Out:
# Top 10 students by total score :
#             name department  total_score  attendance_percentage
# 16  Manoj Pandey      Civil          210                     65

# %%
math_above_80=df[df['math_score']>80]
print(f"Number of students with math score above 80: {len(math_above_80)}")
# Out:
# Number of students with math score above 80: 11

# %%
#5
att_above_90=df[df['attendance_percentage']>90]
print(f"Number of students with attendance above 90%: {len(att_above_90)}")
# Out:
# Number of students with attendance above 90%: 10

# %% [markdown]
# MINI PROJECT : Student Date Explorer
# Objective:
# Create a Student Performance Explorer usinbg Python and Pandas to analyse studnet data and generate a detailed report
#
# Dataset Columns:
#
# name
#
# gender
#
# department
#
# math_score
#
# programming_score
#
# attendance_percentage
#
# total_score
#
# Tasks to perform:
#
# 1.Display project title
#
# print a formayter title with seperated lines
#
# 2.Dataset Overview
#
# Display
#
# -total number of students
#
# -Total number of columns
#
# -Number of unique departments
#
# 3.Department-wise analysis
#
# Display the count of students in each department
#
# 4.Score Analysis
#
# Find and display:
#
# -Highest math score
#
# -Lowest math score
#
# -Average programming score
#
# -Average attendance percentage
#
# 5.Gender-wise Analysis:
#
# Calculate and display average total score grouped by gender
#
# 6.Top Preferences:
#
# Display the top 5 students based on the total_score
#
# show:Student Name,Department,Total Score
#
# 7.Attendance Analysis:
#
# Find students wghose attendance is below 75%
#
# Display:
#
# -Name
#
# -Department
#
# -Attendance Percentage
#
# if all students have attendance above 75%
#
# print a suitable message
#
# Concepts to Use:
#
# -pandas,DataFrame,groupby(),value_counts(),mean(),max(),min(),sort_values(),iterrows(),Conditional statements,f-strings

# %%
import pandas as pd
df = pd.read_csv('student_performance.csv')
df['total_score'] = (
    df['math_score'] +
    df['science_score'] +
    df['english_score'] +
    df['programming_score']
)

# %%
print("=" * 50)
print("      STUDENT PERFORMANCE EXPLORER")
print("=" * 50)
# Out:
# ...
#       STUDENT PERFORMANCE EXPLORER
# ...

# %%
print("\nDATASET OVERVIEW")
print("-" * 30)

print(f"Total number of students : {df.shape[0]}")
print(f"Total number of columns  : {df.shape[1]}")
print(f"Unique departments       : {df['department'].nunique()}")
# Out:
# DATASET OVERVIEW
# ------------------------------
# Total number of students : 30
# Total number of columns  : 14
# Unique departments       : 4

# %%
print("\nDEPARTMENT-WISE ANALYSIS")
print("-" * 30)

dept_count = df['department'].value_counts()

for dept, count in dept_count.items():
    print(f"{dept} : {count} students")
# Out:
# DEPARTMENT-WISE ANALYSIS
# ------------------------------
# Computer Science : 13 students
# Electronics : 6 students
# Mechanical : 6 students
# Civil : 5 students

# %%
print("\nSCORE ANALYSIS")
print("-" * 30)

print(f"Highest Math Score            : {df['math_score'].max()}")
print(f"Lowest Math Score             : {df['math_score'].min()}")
print(f"Average Programming Score     : {df['programming_score'].mean():.2f}")
print(f"Average Attendance Percentage : {df['attendance_percentage'].mean():.2f}")
# Out:
# SCORE ANALYSIS
# ------------------------------
# Highest Math Score            : 95
# Lowest Math Score             : 56
# Average Programming Score     : 67.60
# Average Attendance Percentage : 84.50

# %%
print("\nGENDER-WISE ANALYSIS")
print("-" * 30)

gender_avg = df.groupby('gender')['total_score'].mean().round(2)

for gender, avg in gender_avg.items():
    print(f"{gender} : {avg}")
# Out:
# GENDER-WISE ANALYSIS
# ------------------------------
# Female : 310.67
# Male : 280.67

# %%
print("\nTOP 5 STUDENTS BASED ON TOTAL SCORE")
print("-" * 50)

top_students = df.sort_values(by='total_score', ascending=False).head(5)

for index, row in top_students.iterrows():
    print(f"Name : {row['name']}")
    print(f"Department : {row['department']}")
    print(f"Total Score : {row['total_score']}")
    print("-" * 30)
# Out:
# TOP 5 STUDENTS BASED ON TOTAL SCORE
# --------------------------------------------------
# Name : Ananya Das
# Department : Computer Science
# Total Score : 371
# ------------------------------
# Name : Tanvi Mehta
# Department : Computer Science
# Total Score : 367
# ------------------------------
# Name : Akanksha Yadav
# Department : Computer Science
# Total Score : 365
# ------------------------------
# Name : Arjun Nair
# Department : Computer Science
# Total Score : 356
# ------------------------------
# Name : Divya Singh
# Department : Computer Science
# Total Score : 356
# ------------------------------

# %%
print("\nSTUDENTS WITH ATTENDANCE BELOW 75%")
print("-" * 40)

low_attendance = df[df['attendance_percentage'] < 75]

if len(low_attendance) > 0:

    for index, row in low_attendance.iterrows():
        print(f"Name : {row['name']}")
        print(f"Department : {row['department']}")
        print(f"Attendance Percentage : {row['attendance_percentage']}%")
        print("-" * 30)

else:
    print("All students have attendance above 75%")
# Out:
# STUDENTS WITH ATTENDANCE BELOW 75%
# ----------------------------------------
# Name : Meera Joshi
# Department : Electronics
# Attendance Percentage : 72%
# ------------------------------
# Name : Rahul Mishra
# Department : Mechanical
# Attendance Percentage : 68%
# ------------------------------
# Name : Manoj Pandey
# Department : Civil
# Attendance Percentage : 65%
# ------------------------------
# Name : Harish Pillai
# Department : Electronics
# Attendance Percentage : 74%
# ------------------------------
# Name : Sanjay Dubey
# Department : Civil
# Attendance Percentage : 70%
# ------------------------------
# Name : Sunita Pillai
# Department : Civil
# Attendance Percentage : 73%
# ------------------------------

# %%
# STUDENT DATA EXPLORER

import pandas as pd
df = pd.read_csv('student_performance.csv')

# Create total_score column
df['total_score'] = (
    df['math_score'] +
    df['science_score'] +
    df['english_score'] +
    df['programming_score']
)

# 1. PROJECT TITLE
print("=" * 50)
print("      STUDENT PERFORMANCE EXPLORER")
print("=" * 50)

# 2. DATASET OVERVIEW
print("\nDATASET OVERVIEW")
print("-" * 30)

print(f"Total number of students : {df.shape[0]}")
print(f"Total number of columns  : {df.shape[1]}")
print(f"Unique departments       : {df['department'].nunique()}")

# 3. DEPARTMENT-WISE ANALYSIS
print("\nDEPARTMENT-WISE ANALYSIS")
print("-" * 30)

dept_count = df['department'].value_counts()
for dept, count in dept_count.items():
    print(f"{dept} : {count} students")

# 4. SCORE ANALYSIS

print("\nSCORE ANALYSIS")
print("-" * 30)

print(f"Highest Math Score            : {df['math_score'].max()}")
print(f"Lowest Math Score             : {df['math_score'].min()}")
print(f"Average Programming Score     : {df['programming_score'].mean():.2f}")
print(f"Average Attendance Percentage : {df['attendance_percentage'].mean():.2f}")

# 5. GENDER-WISE ANALYSIS

print("\nGENDER-WISE ANALYSIS")
print("-" * 30)

gender_avg = df.groupby('gender')['total_score'].mean().round(2)

for gender, avg in gender_avg.items():
    print(f"{gender} : {avg}")


# 6. TOP 5 STUDENTS
print("\nTOP 5 STUDENTS BASED ON TOTAL SCORE")
print("-" * 50)

top_students = df.sort_values(by='total_score', ascending=False).head(5)

for index, row in top_students.iterrows():
    print(f"Name : {row['name']}")
    print(f"Department : {row['department']}")
    print(f"Total Score : {row['total_score']}")
    print("-" * 30)

# 7. ATTENDANCE ANALYSIS
print("\nSTUDENTS WITH ATTENDANCE BELOW 75%")
print("-" * 40)

low_attendance = df[df['attendance_percentage'] < 75]

if len(low_attendance) > 0:

    for index, row in low_attendance.iterrows():
        print(f"Name : {row['name']}")
        print(f"Department : {row['department']}")
        print(f"Attendance Percentage : {row['attendance_percentage']}%")
        print("-" * 30)

else:
    print("All students have attendance above 75%")
# Out:
# ...
#       STUDENT PERFORMANCE EXPLORER
# ...
#
# DATASET OVERVIEW
# ------------------------------
# Total number of students : 30
# Total number of columns  : 14
# Unique departments       : 4
#
# DEPARTMENT-WISE ANALYSIS
# ------------------------------
# Computer Science : 13 students
# Electronics : 6 students
# Mechanical : 6 students
# Civil : 5 students
#
# SCORE ANALYSIS
# ------------------------------
# Highest Math Score            : 95
# Lowest Math Score             : 56
# Average Programming Score     : 67.60
# Average Attendance Percentage : 84.50
#
# GENDER-WISE ANALYSIS
# ------------------------------
# Female : 310.67
# Male : 280.67
#
# TOP 5 STUDENTS BASED ON TOTAL SCORE
# --------------------------------------------------
# Name : Ananya Das
# Department : Computer Science
# Total Score : 371
# ------------------------------
# Name : Tanvi Mehta
# Department : Computer Science
# Total Score : 367
# ------------------------------
# Name : Akanksha Yadav
# ...
